# %%
import pandas as pd


combined_data = pd.read_csv('merged firm and yearly data.csv')

# %%
import plotly.express as px




box1 = px.box(combined_data, y="Total Current Liabilities", width= 500, height= 500, points= 'outliers')
box1.show()

box2 = px.box(combined_data, y="Total Debt", width= 500, height= 500, points= 'outliers')
box2.show()

# %%
# treatment


# Calculate the IQR
Q1 = combined_data.quantile(0.25)
Q3 = combined_data.quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# # Identify the outliers
# outliers = combined_data[(combined_data < lower_bound) | (combined_data > upper_bound)].dropna()

# # Remove the outliers
# df_clean = combined_data[~((combined_data < lower_bound) | (combined_data > upper_bound)).any(axis=1)]



# clip the data column-wise
clipped_df = combined_data.clip(lower=lower_bound, upper=upper_bound, axis=1)

print(clipped_df)
# Out:
#        Unnamed: 0  RIC  Date  Total Current Assets  Total Current Liabilities  \
# 0               0  NaN  2009            434.373405                 483.824655
# 1               1  NaN  2010            579.778906                 580.095207
# 2               2  NaN  2011            598.968478                 607.694345
# 3               3  NaN  2012            615.523874                 601.137943
# 4               4  NaN  2013            748.229068                 814.064189
# ...           ...  ...   ...                   ...                        ...
# 24474       24474  NaN  2017            418.425922                 593.193096
# 24475       24475  NaN  2018            388.901048                 565.800430
# 24476       24476  NaN  2019            459.703083                 534.734499
# 24477       24477  NaN  2020            451.245129                 495.033610
# 24478       24478  NaN  2021            466.063443                 443.711453
#
# ...

# %%
# post outlier removal visualization


box3 = px.box(clipped_df, y="Total Current Liabilities", width= 500, height= 500, points= 'outliers')
box3.show()

box4 = px.box(clipped_df, y="Total Debt", width= 500, height= 500, points= 'outliers')
box4.show()

# %%
# export data after outlier removal

df_clean.to_csv('clean data.csv')
