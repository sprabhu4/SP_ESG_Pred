# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_firm = pd.read_csv("Firm Data.csv")

# %%
df_firm.head()
# Out:
#       RIC        Date  Total Current Assets  Total Current Liabilities  \
# 0  BVIC.L  31/12/2009            434.373405                 483.824655
# 1  BVIC.L  31/12/2010            579.778906                 580.095207
# 2  BVIC.L  31/12/2011            598.968478                 607.694345
# 3  BVIC.L  31/12/2012            615.523874                 601.137943
# 4  BVIC.L  31/12/2013            748.229068                 814.064189
#
#    Total Debt  Total Assets, Reported  Net Income - Actual  Revenue Per Share  \
# 0  718.957376             1361.504594           107.309409           7.068281
# 1  901.298414             1655.358922           139.656087           8.006665
# 2  893.154869             1660.096296           122.255528           7.912984
# 3  907.121844             1658.099764           100.765756           7.914423
# 4  895.874010             1714.940377           133.919162           8.716901
#
#    Total Revenue  Total Equity  \
# 0    1561.383359     -3.988004
# ...

# %%
df_firm[df_firm['RIC'] == "0973.HK"]
# Out:
#           RIC        Date  Total Current Assets  Total Current Liabilities  \
# 7748  0973.HK  31/12/2009            240.811949                 188.057347
# 7749  0973.HK  31/12/2010            253.856442                 280.511760
# 7750  0973.HK  31/12/2011            702.119070                 209.480573
# 7751  0973.HK  31/12/2012            747.762389                 220.512102
# 7752  0973.HK  31/12/2013            775.893097                 227.765173
# 7753  0973.HK  31/12/2014            840.266035                 287.871444
# 7754  0973.HK  31/12/2015            770.856358                 217.300986
# 7755  0973.HK  31/12/2016            810.574702                 231.735485
# 7756  0973.HK  31/12/2017            803.085000                 225.186889
# 7757  0973.HK  31/12/2018            887.400508                 289.198147
# 7758  0973.HK  31/12/2019            623.072350                 289.278744
# ...

# %%
df_return = pd.read_csv("yearly_return.csv")

# %%
df_return.head()
# Out:
#        RIC  Date  returns_monthly
# 0  0973.HK  2009         0.000000
# 1  0973.HK  2010        46.444961
# 2  0973.HK  2011       -23.899519
# 3  0973.HK  2012        51.000108
# 4  0973.HK  2013       -34.498730

# %%
df_firm
# Out:
#             RIC        Date  Total Current Assets  Total Current Liabilities  \
# 0        BVIC.L  31/12/2009            434.373405                 483.824655
# 1        BVIC.L  31/12/2010            579.778906                 580.095207
# 2        BVIC.L  31/12/2011            598.968478                 607.694345
# 3        BVIC.L  31/12/2012            615.523874                 601.137943
# 4        BVIC.L  31/12/2013            748.229068                 814.064189
# ...         ...         ...                   ...                        ...
# 24474  AKSEN.IS  31/12/2017            418.425922                 593.193096
# 24475  AKSEN.IS  31/12/2018            388.901048                 565.800430
# 24476  AKSEN.IS  31/12/2019            459.703083                 534.734499
# 24477  AKSEN.IS  31/12/2020            451.245129                 495.033610
# 24478  AKSEN.IS  31/12/2021            466.063443                 443.711453
#
# ...

# %%
df_firm['Date']=pd.to_datetime(df_firm['Date'])

# %%
df_firm['Date']=df_firm['Date'].dt.year

# %%
df_firm = df_firm.drop('Dates',axis=1)

# %%
df_firm
# Out:
#             RIC  Date  Total Current Assets  Total Current Liabilities  \
# 0        BVIC.L  2009            434.373405                 483.824655
# 1        BVIC.L  2010            579.778906                 580.095207
# 2        BVIC.L  2011            598.968478                 607.694345
# 3        BVIC.L  2012            615.523874                 601.137943
# 4        BVIC.L  2013            748.229068                 814.064189
# ...         ...   ...                   ...                        ...
# 24474  AKSEN.IS  2017            418.425922                 593.193096
# 24475  AKSEN.IS  2018            388.901048                 565.800430
# 24476  AKSEN.IS  2019            459.703083                 534.734499
# 24477  AKSEN.IS  2020            451.245129                 495.033610
# 24478  AKSEN.IS  2021            466.063443                 443.711453
#
#        Total Debt  Total Assets, Reported  Net Income - Actual  \
# ...

# %%
df_merged = df_firm.merge(df_return, how="left", on=['RIC', 'Date'])

# %%
df_merged
# Out:
#             RIC  Date  Total Current Assets  Total Current Liabilities  \
# 0        BVIC.L  2009            434.373405                 483.824655
# 1        BVIC.L  2010            579.778906                 580.095207
# 2        BVIC.L  2011            598.968478                 607.694345
# 3        BVIC.L  2012            615.523874                 601.137943
# 4        BVIC.L  2013            748.229068                 814.064189
# ...         ...   ...                   ...                        ...
# 24474  AKSEN.IS  2017            418.425922                 593.193096
# 24475  AKSEN.IS  2018            388.901048                 565.800430
# 24476  AKSEN.IS  2019            459.703083                 534.734499
# 24477  AKSEN.IS  2020            451.245129                 495.033610
# 24478  AKSEN.IS  2021            466.063443                 443.711453
#
#        Total Debt  Total Assets, Reported  Net Income - Actual  \
# ...

# %%
df_merged.to_csv('raw_data.csv', index=False)
